# %% [markdown]
# # HR Employee Attrition & Performance Dataset

# %% [markdown]
# ## Introduction
#
# Employee attrition directly affects organizational performance, costs, and employee morale. Understanding the reasons behind attrition is essential for effective HR decision-making. This project analyzes the HR Employee Attrition & Performance dataset created by IBM data scientists to uncover patterns related to employee turnover using end-to-end data analytics and visualization tools.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## Objective
#
# The objective of this project is to analyze employee attrition using HR data to identify the key factors influencing why employees leave an organization. The analysis uses Excel, Python, SQL, Power BI, and Tableau to generate business-focused insights that help HR managers improve employee retention and workforce planning.

# %% [markdown]
# ### Dataset Overview
#
# The dataset contains fictional employee-level HR data, where each row represents an individual employee. It includes demographic details, job roles, compensation, satisfaction levels, performance ratings, and experience-related variables.
#
# The primary target variable is Attrition, renamed to Left and Stayed for better business understanding. Additional features such as Age Group and Income Level were created to support clearer analysis and visualizations.

# %%
df.size
# Out:
# 51450

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Data Cleaning & Preparation

# %%
df['Attrition_Flag'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# %%
df['Education'] = df['Education'].map(
    {1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'})

# %%
df['JobSatisfaction'] = df['JobSatisfaction'].map({
    1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].map({
    1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].map({
    1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
df['WorkLifeBalance'] = df['WorkLifeBalance'].map({
    1: 'Bad', 2: 'Good', 3: 'Better', 4: 'Best'})

# %%
df['Attrition'] = df['Attrition'].map({
    'Yes': 'Left', 'No': 'Stayed'})

# %% [markdown]
# ### Feature Engineering

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[df['Age'].min(), 29, 39, 49, df['Age'].max()], 
                        labels=['Young', 'Adult', 'Mid Age', 'Senior'])

# %%
df['IncomeBand'] = pd.cut(df['MonthlyIncome'], bins=[df['MonthlyIncome'].min(), 3000, 7000, 12000, df['MonthlyIncome'].max()],
    labels=['Low', 'Medium', 'High', 'Very High'])

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41      Left      Travel_Rarely       1102                   Sales
# 1   49    Stayed  Travel_Frequently        279  Research & Development
# 2   37      Left      Travel_Rarely       1373  Research & Development
# 3   33    Stayed  Travel_Frequently       1392  Research & Development
# 4   27    Stayed      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 4                 2  Below College        Medical              1
#
#    EmployeeNumber  ... TotalWorkingYears TrainingTimesLastYear  \
# 0               1  ...                 8                     0
# ...

# %%
df = df.rename(columns={'BusinessTravel': 'Business Travel','DailyRate': 'Daily Rate','Department': 'Department','DistanceFromHome': 'Distance From Home','Education': 'Education',
    'EducationField': 'Education Field','EmployeeCount': 'Employee Count','EmployeeNumber': 'Employee Number','EnvironmentSatisfaction': 'Environment Satisfaction',
    'Gender': 'Gender','HourlyRate': 'Hourly Rate','JobInvolvement': 'Job Involvement','JobLevel': 'Job Level','JobRole': 'Job Role','JobSatisfaction': 'Job Satisfaction',
    'MaritalStatus': 'Marital Status','MonthlyIncome': 'Monthly Income','MonthlyRate': 'Monthly Rate','NumCompaniesWorked': 'Number of Companies Worked','Over18': 'Over 18',
    'OverTime': 'Over Time','PercentSalaryHike': 'Percent Salary Hike','PerformanceRating': 'Performance Rating','RelationshipSatisfaction': 'Relationship Satisfaction',
    'RelationshipSatisfaction': 'Relationship Satisfaction','StandardHours': 'Standard Hours','StockOptionLevel': 'Stock Option Level','TotalWorkingYears': 'Total Working Years',
    'TrainingTimesLastYear': 'Training Times Last Year','WorkLifeBalance': 'Work Life Balance','YearsAtCompany': 'Years At Company','YearsInCurrentRole': 'Years In Current Role',
    'YearsSinceLastPromotion': 'Years Since Last Promotion','YearsWithCurrManager': 'Years With Current Manager'})

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Attrition Distribution

# %%
sns.countplot(x='Attrition', data=df)
plt.title('Overall Attrition Count')
plt.show()

# %% [markdown]
# #### Attrition by Age Group

# %%
plt.figure()
sns.countplot(x='AgeGroup', hue='Attrition', data=df)
plt.title('Attrition by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Employee Count')
plt.show()

# %% [markdown]
# #### Attrition by Income Level

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'Business Travel', 'Daily Rate', 'Department',
#        'Distance From Home', 'Education', 'Education Field', 'Employee Count',
#        'Employee Number', 'Environment Satisfaction', 'Gender', 'Hourly Rate',
#        'Job Involvement', 'Job Level', 'Job Role', 'Job Satisfaction',
#        'Marital Status', 'Monthly Income', 'Monthly Rate',
#        'Number of Companies Worked', 'Over 18', 'Over Time',
#        'Percent Salary Hike', 'Performance Rating',
#        'Relationship Satisfaction', 'Standard Hours', 'Stock Option Level',
#        'Total Working Years', 'Training Times Last Year', 'Work Life Balance',
#        'Years At Company', 'Years In Current Role',
#        'Years Since Last Promotion', 'Years With Current Manager',
#        'Attrition_Flag', 'AgeGroup', 'IncomeBand'],
#       dtype='object')

# %%
plt.figure()
sns.countplot(x='IncomeBand', hue='Attrition', data=df)
plt.title('Attrition by Income Level')
plt.xlabel('Income Level')
plt.ylabel('Employee Count')
plt.show()

# %% [markdown]
# #### Attrition by Job Role

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Job Role', hue='Attrition', data=df)
plt.xticks(rotation=45)
plt.title('Attrition by Job Role')
plt.show()

# %% [markdown]
# #### Overtime vs Attrition

# %%
sns.countplot(x='Over Time', hue='Attrition', data=df)
plt.title('OverTime vs Attrition')
plt.show()

# %% [markdown]
# #### Monthly Income vs Attrition

# %%
sns.boxplot(x='Attrition', y='Monthly Income', data=df)
plt.title('Monthly Income vs Attrition')
plt.show()

# %% [markdown]
# #### Percent Salary Hike vs Attrition

# %%
sns.boxplot(x='Attrition', y='Percent Salary Hike', data=df)
plt.title('Salary Hike vs Attrition')
plt.show()

# %% [markdown]
# #### Job Satisfaction vs Attrition

# %%
sns.countplot(x='Job Satisfaction', hue='Attrition', data=df)
plt.title('Job Satisfaction vs Attrition')
plt.show()

# %% [markdown]
# #### Work Life Balance vs Attrition

# %%
sns.countplot(x='Work Life Balance', hue='Attrition', data=df)
plt.title('Work Life Balance vs Attrition')
plt.show()

# %% [markdown]
# #### Years at Company vs Attrition

# %%
sns.boxplot(x='Attrition', y='Years At Company', data=df)
plt.title('Years at Company vs Attrition')
plt.show()

# %% [markdown]
# #### Years Since Last Promotion vs Attrition

# %%
sns.boxplot(x='Attrition', y='Years Since Last Promotion', data=df)
plt.title('Years Since Last Promotion vs Attrition')
plt.show()

# %% [markdown]
# #### Distance from Home Analysis

# %%
sns.boxplot(x='Attrition', y='Distance From Home', data=df)
plt.title('Distance From Home vs Attrition')
plt.show()

# %% [markdown]
# #### Correlation Heatmap

# %%
numeric_cols = [
    'Age', 'Monthly Income', 'Distance From Home',
    'Years At Company', 'Years In Current Role',
    'Years Since Last Promotion', 'Percent Salary Hike',
    'Attrition_Flag']

plt.figure(figsize=(10,6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
